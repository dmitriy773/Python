# %%
#1
a = float(input("a: "))
x = float(input("x: "))

if x > 0:
    y = a * x**2 + 1
else:
    y = a * x - 1

print(y)
# Out:
# a:  1
# x:  2
# 5.0

# %%
#2
a = float(input("a: "))
x = float(input("x: "))

if x >= 1:
    y = a * x + 1
else:
    y = x**2 - 1

print(y)
# Out:
# a:  1
# x:  2
# 3.0

# %%
#3
a = float(input("a: "))
x = float(input("x: "))

if x < 0:
    y = 3 * a**2
else:
    y = 4 * a * x - 1

print(y)
# Out:
# a:  3
# x:  4
# 47.0

# %%
#4
a = float(input("a: "))
x = float(input("x: "))

if x > 4:
    y = 2 * a**2
else:
    y = 3 * x - 1

print(y)
# Out:
# a:  5
# x:  6
# 50.0

# %%
#5
a = float(input("a: "))
x = float(input("x: "))

if x > 2:
    y = 2 * a * x - 2
else:
    y = 3 * a**2 - 2 * x

print(y)
# Out:
# a:  7
# x:  8
# 110.0

# %%
#6
a = float(input("a: "))
x = float(input("x: "))

if x > 1:
    y = 2 * a * x**2 - 1
else:
    y = x

print(y)
# Out:
# a:  11
# x:  12
# 3167.0

# %%
#7
a = float(input("a: "))
x = float(input("x: "))

if x > 2:
    y = x**2
else:
    y = 2 * a - 1

print(y)
# Out:
# a:  1
# x:  2
# 1.0

# %%
#8
import math
x = float(input("x: "))

if x > 2:
    y = math.cos(2*x - 1)
else:
    y = math.sin(3*x + 1)

print(y)
# Out:
# x:  4
# 0.7539022543433046

# %%
#9
x = float(input("x: "))

if x > 2:
    y = 2*x**3 - 2*x - 1
else:
    y = 3*x**2 - 2*x + 1

print(y)
# Out:
# x:  5
# 239.0

# %%
#10
a = float(input("a: "))
x = float(input("x: "))

if x > 1:
    y = 2 * a * x**2 - 1
else:
    y = 1 / a

print(y)
# Out:
# a:  5
# x:  2
# 39.0

# %%
#11
import math
a = float(input("a: "))
x = float(input("x: "))

if x > 0:
    y = a * math.sqrt(x) + 1
else:
    y = a * x - 1

print(y)
# Out:
# a:  3
# x:  7
# 8.937253933193773

# %%
#12
import math
a = float(input("a: "))
x = float(input("x: "))

if x >= 0:
    y = math.sqrt(x) + a
else:
    y = a / x - 1

print(y)
# Out:
# a:  6
# x:  9
# 9.0

# %%
#13
a = float(input("a: "))
x = float(input("x: "))

if x > 0:
    y = 1 / x + a
else:
    y = x**2 - 1

print(y)
# Out:
# a:  34
# x:  21
# 34.04761904761905

# %%
#15
import math
x = float(input("x: "))

if x > 2:
    y = math.sqrt(x) - 2
else:
    y = (x - 2)**2 + 1

print(y)
# Out:
# x:  54
# 5.3484692283495345
